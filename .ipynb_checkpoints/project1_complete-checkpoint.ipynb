# %%
import requests
from bs4 import BeautifulSoup
from tqdm import tqdm
import time
import pandas as pd
import string
import nltk
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
from collections import defaultdict
import itertools
from urllib.parse import parse_qs
import glob
import matplotlib.pylab as plt
from collections import Counter
import collections
from nltk.tokenize import word_tokenize

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /Users/CSR/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
def get_job_links_page(page):
    base_url = "https://www.indeed.com/jobs?"
    params = {'q': 'data scientist', 
             'l': 'Boulder, CO'}
    

    # start = "https://www.indeed.com/jobs?q=Data+Scientist&l=Denver%2C+CO"
    # use a fake header
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.87 Safari/537.36'}
    params['start'] = 20 * (page-1)

    page = requests.get(base_url, params=params, headers=headers)
    # test = requests.get(start, headers=headers)
    
    soup = BeautifulSoup(page.text, "html.parser")
    links = soup.find_all("a")
    
    # build a list of links
    some_links = []

    for l in links:
        try:
            hyperlink = l.attrs.get('href')
            if "/rc/clk?" in hyperlink:
                some_links.append(l.attrs.get('href'))
        except:
            pass
    
    job_links = ["https://www.indeed.com{}".format(x)
             for x in some_links
             ]
    
    return job_links

# %%
links = [get_job_links_page(x) for x in range(1, 40)] # getting a link for 39 pages

# %%
merged = list(itertools.chain(*links))
len(merged)
merged[0] # getting a link for 39 pages
# Out:
# 'https://www.indeed.com/rc/clk?jk=c9d84c941c6b6d2f&fccid=4600afcfb0f58ad6&vjs=3'

# %%
def get_filename_from_url(some_url):
    parsed = parse_qs(some_url)
    fccid =  parsed.get('fccid')[0]
    other_id = parsed.get('https://www.indeed.com/rc/clk?jk')[0]
    return fccid+other_id+ ".html"

# %%
get_filename_from_url(merged[0]) # file name for each html file
# Out:
# '4600afcfb0f58ad6c9d84c941c6b6d2f.html'

# %%
len(set([get_filename_from_url(x) for x in merged])) # the total number of html files(jobs) parsed and saved locally.
# Out:
# 243

# %%
#downloading each html file as a soup object
def download_job_page(link):
    save_name = get_filename_from_url(link)
    
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.87 Safari/537.36'}
    test = requests.get(link, headers=headers)
    soup = BeautifulSoup(test.text, "html.parser")
    
    with open('data_scienceBoulder_{}'.format(save_name), 'w') as f:
        f.write(str(soup))

# %%
for link in tqdm(merged):
    try:
        download_job_page(link)
    except Exception as e:
        print(str(e), link)
    finally:
        time.sleep(1)
# Out:
#   6%|▌         | 22/373 [00:30<08:11,  1.40s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-39f210f6ca4f> in <module>()
#       5         print(str(e), link)
#       6     finally:
# ----> 7         time.sleep(1)
#
# KeyboardInterrupt:

# %%
html = glob.glob('*.html')
len(html) # the total number of html files(jobs) parsed and saved locally.
# Out:
# 1528

# %%
html_divs = []

for html_file in html:
    with open(html_file, 'r',encoding="ISO-8859-1") as f:
        _data = BeautifulSoup(f.read(), "html.parser")
        try:
            has_span_job_summary = _data.find("span", id="job_summary").get_text()
            html_divs.append(has_span_job_summary)
        except:
            print('The job summary field does not exist.')
        
len(html_divs) # total numbers of job postings saved locally.
# Out:
# The job summary field does not exist.
# The job summary field does not exist.
# The job summary field does not exist.
# The job summary field does not exist.
# The job summary field does not exist.
# The job summary field does not exist.
# The job summary field does not exist.
# 1521

# %%
jobs = pd.DataFrame(html_divs)
jobs.columns = ['job_summary']
jobs.head(20)
# Out:
#                                           job_summary
# 0   Data Analyst\nCommunity Reach Center (CRC) is ...
# 1   Public Consulting Group, Inc. (PCG) is a leadi...
# 2   Job Summary\nThe Department of Computer Scienc...
# 3   Department: Clinical Application Services\nHou...
# 4   Accelerate Your Career\nDrive global technolog...
# 5   Who We Are:\n\n\nBall Aerospace leads the way ...
# 6   Job Summary\n\nUnder minimal supervision, desi...
# 7   Data Engineer (multiple positions)\nDatalere t...
# 8   Collect, review, and report on data.\nCollect ...
# 9   At FedEx Office, team members with a passion f...
# 10  Job Description\nAt Amazon Web Services (AWS),...
# 11  The Google Technical Services Consumers team i...
# 12  USN - Danone North America Inc, a subsidiary o...
# 13  Data Analyst\nWe are looking for a highly moti...
# 14  Who We Are:\n\n\nBall Aerospace leads the way ...
# 15  Who We Are:\n\n\nBall Corporation, since its f...
# 16  Who We Are:\n\n\nBall Aerospace leads the way ...
# 17  Who We Are:\n\n\nBall Aerospace leads the way ...
# 18  Do you want to help eliminate barriers between...
# 19  Employee Services provides the University of C...

# %%
jobs.shape
# Out:
# (1521, 1)

# %%
df1=pd.read_csv('hacker_news.csv')
del df1['source']
df1.rename(columns={'desc': 'job_summary'}, inplace=True)
df1.head()
# Out:
#                                          job_summary
# 0  Photofeeler (<a href="https:&#x2F;&#x2F;www.ph...
# 1  Q-Branch Labs (<a href="https:&#x2F;&#x2F;www....
# 2  Worldwide, REMOTE, full time or part time -- 1...
# 3  Lendable | Senior Software Engineers, Senior D...
# 4  Gambit Research Ltd (<a href="http:&#x2F;&#x2F...

# %%
all_jobs=pd.concat([df1,jobs])

# %%
all_jobs.job_summary.unique()
# Out:
# array(['Photofeeler (<a href="https:&#x2F;&#x2F;www.photofeeler.com" rel="nofollow">https:&#x2F;&#x2F;www.photofeeler.com</a>) | Software Engineers, Marketing Roles | REMOTE or Onsite near Boulder, CO<p>If you were a fan of the old OkCupid blog or Christian Rudder&#x27;s &quot;Dataclysm,&quot; you will love it here.<p>Photofeeler is a tool for photo feedback, but we&#x27;re primarily a data science company. We do math to maximize the statistical value of small, noisy data samples. Our company is changing the future of online profiles.<p>The gig offers unparalleled freedom without beauracratic nonsense (think: can work remote, work flexible hours, no unnecessary meetings). Our users are eager and enthusiastic for everything that we build.<p>More info: <a href="https:&#x2F;&#x2F;www.photofeeler.com&#x2F;jobs" rel="nofollow">https:&#x2F;&#x2F;www.photofeeler.com&#x2F;jobs</a>',
#        'Q-Branch Labs (<a href="https:&#x2F;&#x2F;www.q-branch.net" rel="nofollow">https:&#x2F;&#x2F;www.q-branch.net</a>) | Marketing Director, Hardware Product Manager, Python Developer | FULL-TIME | London | ONSITE | £50-75K + equity<p>Join a team helping to protect smart homes from the internet of insecure things.  We all know IoT and connected-devices are a security nightmare:  infrequently updated, often insecure by design, and a constantly growing source of zombie devices for botnet herders.  Help a seed-funded startup solve this problem for the huge mass of people who are not security&#x2F;networking experts and need an easy to install and easy to use solution!<p>Marketing Director - Q-Branch is looking for an ambitious marketing director who has experience in crafting a startup marketing plan from the ground up; messaging, PR, advertising and design.  Crowdfunding and social media management experience strongly desired.<p>Hardware Product Manager - We need someone with experience in delivering a consumer hardware product, from CAD design and injection molding to assembly and shipping.  We need someone with experience in sourcing parts, performing hardware QA and certification, and handling the end-to-end pipeline from development to delivery.<p>Python Developer - Q-Branch is also looking for an experienced Python developer with a strong linux&#x2F;unix background. Role will involve devops work (Ansible&#x2F;Kubernetes&#x2F;Terraform on AWS) as well as work on a large-scale event processing pipeline feeding a variety of analytics engines. Some experience in cyber-security, security data analytics, and machine learning are all major wins for a candidate.<p>Contact us at jobs@q-branch.net for more info or check us out on AngelList (<a href="https:&#x2F;&#x2F;angel.co&#x2F;q-branch-labs&#x2F;jobs" rel="nofollow">https:&#x2F;&#x2F;angel.co&#x2F;q-branch-labs&#x2F;jobs</a>)',
#        'Worldwide, REMOTE, full time or part time -- 100% flexibility. $70-100&#x2F;hr. Expert Interviewer at Karat (<a href="https:&#x2F;&#x2F;karat.io" rel="nofollow">https:&#x2F;&#x2F;karat.io</a>)<p>Work from anywhere in the world that has a solid internet connection. Work as much or as little as you want. Work any day, any time of day, any number of hours -- you can do 0 one week, 50 the next week, and back to 0 the next week. Only requirement there is that we want you to roughly average at least 10 hours a week, or else the training&#x2F;time investment doesn&#x27;t make as much sense from your end or ours.<p>I know the above might sound a little strange, so a bit about the company for context: Karat is a Seattle-based startup that does software engineering interviews on behalf of other companies -- primarily first-round phone screens. Quickly-growing companies can spend a significant fraction of their engineers&#x27; time interviewing; we help take the load off. We&#x27;ve done a lot to make the interview experience better for all stakeholders that I could write whole essays about, but suffice it to say that candidates love working with us, clients love working with us, and we&#x27;re well-funded and growing quickly as a result.<p>Because of this quickly-growing demand, we&#x27;re looking to hire more Expert Interviewers. The ideal candidate is a software engineer with strong written and verbal English skills with at least a few years of professional experience. Interviewing experience would be great, but we spend 25 hours (paid) training you before you even start, so if you&#x27;re strong technically and love working with people we can usually make it work :) Interviews are conducted over video chat, using a collaborative code editor.<p>Some of our interviewers are freelancers who use our scheduling model to backfill hours; others are full timers at top tech companies looking to make some extra cash; others have quit their jobs to work with us full time; some are digital nomads; one of our interviewers is road tripping around North America for a year and a half, doing anywhere from zero to 40 interviews each week depending on where he is and what the weather&#x27;s like.<p>The application form is here: <a href="https:&#x2F;&#x2F;jobs.lever.co&#x2F;karat&#x2F;d44ab283-c7c0-4bbd-b8c3-4dc0ced64c86?lever-origin=applied&amp;lever-source=HNWH" rel="nofollow">https:&#x2F;&#x2F;jobs.lever.co&#x2F;karat&#x2F;d44ab283-c7c0-4bbd-b8c3-4dc0ced6...</a><p>I know it&#x27;s a pretty unique job, so if you have any questions reply here or email me at josh@karat.io and I&#x27;m happy to talk through any of it.<p>P.S. We&#x27;re also hiring for our internal team -- particularly looking for senior engineers right now; for those we generally prefer local (Seattle) candidates, though we do cover relocation. More details on those here: <a href="https:&#x2F;&#x2F;karat.io&#x2F;careers" rel="nofollow">https:&#x2F;&#x2F;karat.io&#x2F;careers</a>, or feel free to email me if you have any questions.',
#        ...,
#        'Analyst - Corporate Strategy \x96 Denver CO\n\nDescription: The Analyst will work on high priority strategic initiatives as part of a corporate strategy team that works directly with the senior leaders of DaVita Kidney Care and the Population Health Management (DaVita Medical Group) businesses within DaVita Inc. The team is responsible both for supporting short term strategic needs, as well as guiding our long term strategy of being a global provider of integrated care. Work streams will likely involve:\nDeveloping creative strategies for enterprise growth across both kidney care and population health managementEvaluating opportunities that drive core business expansion, international presence and innovation in white spaceCreating transformational integrated care business models that drive new value for patients, providers and the businessForming specific strategies for subsidiariesAnalyzing market dynamics, financials, growth opportunities, and threatsInforming enterprise initiatives on healthcare reform, macro trends and policyManaging dynamic, complex problems involving key stakeholders (physicians, patients, health systems, payers, etc.)\n\nThe Analyst will work with a team of highly motivated individuals with consulting, finance and clinical experience, and is expected to effectively manage individual work streams and communicate analyses within the team and with senior executives.\n\nHere is what you can expect when you join our Village:A "community first, company second" culture based on Core Values that really matter.Clinical outcomes consistently ranked above the national average.Award-winning education and training across multiple career pathsPerformance-based rewards based on stellar individual and team contributions.A comprehensive benefits package designed to enhance your health, your financial well-being and your future.Dedication, above all, to caring for our patients\n\nEssential duties and responsibilities:Work collaboratively within team and across organizationDrive analysis of assigned projects and initiatives, including developing work plansExecute structured, hypothesis-driven problem solvingBuild both financial and operational models to drive towards answersWork effectively with qualitative and quantitative data to form strategic insightsCoach younger analysts on the teamConvey findings in a cohesive story, including summarizing insights from analysis; identifying next steps; developing implementation plans\nEffectively communicate with all levels of management\nHere is what you can expect when you join our Village:\nA "community first, company second" culture based on Core Values that really matter.\nClinical outcomes consistently ranked above the national average.\nAward-winning education and training across multiple career paths to help you reach your potential.\nPerformance-based rewards based on stellar individual and team contributions.\nA comprehensive benefits package designed to enhance your health, your financial well-being and your future.\nDedication, above all, to caring for patients suffering from chronic kidney failure across the nation.\nQualifications\n\n2+ yrs experience at top tier investment bank / consulting firm / private equity / corporate finance or corporate strategy department\nStrong interpersonal and leadership skills to build credibility as a "peer\x94 across all levels\nPersonal values in line with DaVita\'s values of Service Excellence, Integrity, Team, Continuous Improvement, Accountability, Fulfillment & Fun\nAnalytical skills: Strong quantitative background; ability to create detailed financial and operational models\nProblem solving skills: Ability to structure ambiguous problems, think creatively, generate and test hypotheses\nPresentation skills: Comfortable putting together storylines in PowerPoint\nCommunication skills: Ability to synthesize and convey research/analyses to senior management\nManagement skills: Ability to drive multiple pieces of work forward  ...
#        'Description:\nThe VP Analyst will interface with clients and focus on a variety of challenging analytical projects, particularly in stress testing, risk measurement, valuation, and loan credit modeling. The ideal candidate will have experience modeling the cash flows and risks associated with one or more of the following balance sheet categories: consumer, residential mortgage, and commercial mortgage related loans and securities; consumer deposits; mortgage servicing rights.\n\n\nSupport the development and execution of quantitative models around stress testing, credit losses (CECL/IFRS9), consumer deposit behavior, loan prepayments, loan and security valuation, and risk advisory services\nEnsure timely completion of project milestones and client deliverables are met using the highest standards\nComplete as directed analysis to support existing client requests, efforts to engage new clients, or ad hoc internal projects\nBuild and maintain ongoing, long-term relationships with existing and potential clients.\n\nRequirements:\n\n2+ years of experience using advanced quantitative analysis and applied statistical techniques, including regression, feature selection, model specification, time series forecasting, economic models, data mining, supervised and unsupervised machine learning, survival analysis, credit risk modeling, prepayment modeling, sensitivity and uncertainty analysis, back-testing\n2+ years financial services experience with a preference for skills acquired in a function responsible for CCAR/DFAST stress testing, capital management, risk management, CECL model creation, loan loss reserve modeling, loan or bond pricing\nDemonstrated ability in developing and managing sophisticated financial models and performing ad hoc analysis to support risk, valuation, pricing, and capital decisions\nAdvanced statistical software programming skills, preferably R and Python\nAdvanced proficiency in Excel/ VBA and database applications\nStrong organizational skills and communication skills\nMasters in a quantitative discipline required, PhD preferred\nHandle multiple projects simultaneously and maintain excellent client relations\nFRM or CQF participation/certification a plus\nEnjoys an entrepreneurial environment\n\n',
#        'CenturyLink (NYSE: CTL) is a global communications and IT services company focused on connecting its customers to the power of the digital world. CenturyLink offers network and data systems management, big data analytics, managed security services, hosting, cloud, and IT consulting services. The company provides broadband, voice, video, advanced data and managed network services over a robust 265,000-route-mile U.S. fiber network and a 360,000-route-mile international transport network. Visit CenturyLink for more information.\n\n\n\nJob Description\n\nThe Managed SOC Analyst\'s primary function in a 24/7 environment is to provide managed security operations center (SOC) analysis associated with customer monitoring activities using the Splunk SIEM solution and scanning through the processing and management of incident and request tickets, as they are assigned. Some investigation and threat hunting are also in scope. The responsibilities include monitoring alerts, receiving and reviewing escalations from other Tier 1 Analysts, customers, and other internal groups, as well as managing the full incident handling lifecycle with customers. The Analyst is expected to contribute to internal documentation and adherence to SLA targets and requirements. The role includes log monitoring and root cause analysis, and interfacing with clients and associates as needed to resolve complex cases. These Analysts are also expected to participate in, and contribute to planning and implementation of strategic and operational projects in efforts to achieve overall MSS goals. Analysts are expected to be able to troubleshoot problems with little oversight, take ownership and work independently as needed to resolve customer issues.\n\nDuties and Responsibilities\n\nMonitoring the Splunk SIEM solution and performing duties related to continuous process improvement, client escalations, documentation and review.\nMonitoring events from various SIEM related tools (i.e. ArcSight, QRadar)\nWorking with SOC management on integrating with shared managed, multi-tenant SOC environment\nMaintain Industry Training - This involves keeping up-to-date on security technologies, threats, and risk mitigation techniques\nCase Management - ensuring the case management process is handled efficiently in a timely manner.\nSOC Activity Log -creating, reviewing, and maintaining entries, working with other analysts Report Creation - creating temporary or permanent reports for customers, as requested.\nCustomer Meetings - attending and/or leading customer meetings as part of incident response and incident handling\nTraining and Mentoring SOC personnel - Security Analysts are responsible for training new SOC employees\nRegularly performing tuning and filtering SIEM alerts and monitoring components to ensure only relevant security data is gathered\nProjects - May work on security projects as assigned\n\n\nShift Responsibilities\n\nThe Security Analyst is responsible for the following shift duties:\n\nDaily Traffic Review - replaying traffic from previous shifts and reviewing customer reports to ensure potential security incidents were not missed by other Analyst.\nImprove their knowledge of the customer environment, intrusion detection, methodologies, and intrusion detection services with the support of on-going training from the analysts and self-study\nReview SOC Activity log, cases and other monitoring tools for complete understanding of previous shift activities and incidents\nHandle event incident response, case management, and customer notification\nProviding process and operational improvement suggestions\nReview, write, and update documentation (such as SOPs, MOPs, and TTPs)\nDaily Case Management - the Security Analyst will review open cases and provide follow up that may be required\nReport generation on demand and scheduling using available tools\n\n\nQualifications\n\nAble to pass Public Trust Adjudication back ground and credit check\nAt least 1 years Informati ...
#       dtype=object)

# %%
def load_skills_list():
    import pandas as pd
    skills = pd.read_csv('skill_phrases-JBM.csv', encoding="ISO-8859-1")
    skills.columns = ['skill_name']
    skills['skill_name'] = skills.skill_name.map(lambda x: 
                                               x.lower().strip())
    return skills.skill_name.tolist()

# %%
skills = pd.read_csv('skill_phrases-JBM.csv', encoding="ISO-8859-1")
skills.columns = ['skill_name']
skills['skill_name'] = skills.skill_name.map(lambda x: 
                                           x.lower().strip())
skills.head()
# Out:
#             skill_name
# 0          geodatabase
# 1                  e2e
# 2             analysts
# 3                 hive
# 4  applied mathematics

# %%
list_of_skills = skills.skill_name.tolist() # All skills we know of
list_of_skills = [x.replace("\xa0", " ").replace("\x92s", " ") for x in list_of_skills]

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /Users/CSR/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
#make a big string of all job descriptions
job_string = " ".join(all_jobs.job_summary.tolist())
job_tokens = nltk.word_tokenize(job_string)
job_tokens = [word for word in job_tokens if len(word) >= 1] # remove space 
job_tokens = [word for word in job_tokens if not word in stop_words] # remove english language stop words 
job_tokens = [word.lower().strip() for word in job_tokens if not word in string.punctuation]

assert(type(job_tokens) == list)
filtered = Counter([x for x in job_tokens if x in list_of_skills])

# %%
filtered.most_common(50) # looking across skill frequency for all jobs, one way to do it
# Out:
# [('development', 3180),
#  ('software', 3088),
#  ('analysis', 2657),
#  ('research', 1893),
#  ('design', 1852),
#  ('engineering', 1831),
#  ('communication', 1405),
#  ('engineers', 1339),
#  ('analyst', 1297),
#  ('analytics', 1138),
#  ('it', 935),
#  ('python', 856),
#  ('developer', 856),
#  ('analytical', 848),
#  ('manage', 837),
#  ('web', 826),
#  ('stack', 823),
#  ('sql', 749),
#  ('planning', 710),
#  ('leadership', 707),
#  ('access', 677),
#  ('code', 673),
#  ('analyze', 640),
#  ('excel', 625),
#  ('models', 597),
#  ('react', 575),
#  ('finance', 556),
#  ('bi', 540),
#  ('analysts', 528),
#  ('cloud', 524),
#  ('modeling', 519),
#  ('database', 507),
#  ('mobile', 492),
#  ('programming', 475),
#  ('writing', 473),
#  ('backend', 473),
#  ('aws', 472),
#  ('statistical', 462),
#  ('javascript', 437),
#  ('healthcare', 434),
#  ('java', 396),
#  ('social', 392),
#  ('agile', 392),
#  ('interpersonal', 373),
#  ('model', 369),
#  ('hardware', 367),
#  ('databases', 355),
#  ('collaborate', 354),
#  ('ms', 348),
#  ('frontend', 346)]

# %%
def get_matching_skills_for_search_kw(search_term, dataframe_name, list_of_skills):

    
    matches = defaultdict(int)

    for index, row in dataframe_name.iterrows():
        job_desc = row.job_summary # local specificity 
        job_tokens = nltk.word_tokenize(job_desc)
        job_tokens = [word for word in job_tokens if len(word) >= 1] # remove space 
        job_tokens = [word for word in job_tokens if not word in stop_words] # remove english language stop words 
        job_tokens = [word.lower().strip() for word in job_tokens if not word in string.punctuation ] 
        
        if search_term in job_tokens:
            for skill in list_of_skills:
                if (skill in job_tokens):
                    matches[skill] += 1
                    
    return Counter(matches)

# %%
LIST_OF_QUERIES = ['sql', 'python', 'javascript', 'java', 'excel'] # obviously use more

all_matches =  { query: get_matching_skills_for_search_kw(query, 
                                                all_jobs, 
                                                list_of_skills) 
               for query in LIST_OF_QUERIES  }

# %%
all_matches
# all_matches ===> {query: counter object, query: counter object}
# Out:
# {'sql': Counter({'it': 146,
#           'developer': 83,
#           '.net': 26,
#           'angular': 11,
#           'github': 4,
#           'stack': 63,
#           'sql': 474,
#           'django': 12,
#           'php': 33,
#           'development': 315,
#           'javascript': 243,
#           'java': 166,
#           'software': 276,
#           'python': 356,
#           'ruby': 32,
#           'mobile': 55,
#           'web': 246,
#           'node.js': 28,
#           'jquery': 52,
#           'mysql': 24,
#           'postgres': 10,
#           'server': 111,
#           'android': 17,
#           'ms': 99,
#           'ios': 15,
#           'c': 39,
#           'react': 31,
#           'models': 132,
#           'hadoop': 56,
#           'linux': 78,
#           'css': 28,
#           'js': 9,
#           'frontend': 10,
#           'azure': 25,
#           'cloud': 63,
#           'c++': 20,
#           'controls': 19,
#           'modeling': 232,
#           'docker': 23,
#           'databases': 115,
#           'restful': 6,
#           'backend': 50,
#           'initiative': 33,
#           'code': 80,
#           'api': 32,
#           'postgresql': 22,
#           'aws': 46,
#           'front-end': 18,
#           'engineering': 296,
#           'oracle': 97,
#           'database': 149,
#           'full-stack': 15,
#           'analytics': 406,
#           'statistics': 212,
#           'apis': 26,
#           'communication': 279,
#           'scripting': 43,
#           'interpersonal': 96,
#           'git': 42,
#           'engineers': 68,
#           'healthcare': 54,
#           'app': 24,
#           'networking': 7,
#           'social': 36,
#           'unix': 12,
#           'finance': 74,
#           'shell': 15,
#           'coding': 100,
#           'programming': 246,
#           'cron': 9,
#           'html': 36,
#           'sass': 3,
#           'angularjs': 10,
#           'dynamodb': 5,
#           'facebook': 5,
#           'cms': 5,
#           'node': 7,
#           'ai': 7,
#           'planning': 97,
#           'tdd': 4,
#           'access': 114,
#           'es6': 3,
#           'apps': 18,
#           'nosql': 37,
#           'back-end': 12,
#           'manage': 147,
#           'analysts': 248,
#           'agile': 202,
#           'ui': 17,
#           'qa': 32,
#           'ux': 4,
#           'graphql': 3,
#           'optimization': 78,
#           'webpack': 6,
#           'crm': 14,
#           'personalization': 11,
#           'adobe': 20,
#           'scrum': 24,
#           'qlikview': 11,
#           'analyst': 223,
#           'data-driven': 39,
#           'statistical': 111,
#           'analytic': 106,
#           'redshift': 15,
#           'collaborative': 58,
#           'redis': 9,
#           'r': 125,
#           'elasticsearch': 20,
#           'analysis': 572,
#           'investing': 12,
#           'vue': 2,
#           'pandas': 34,
#           'algorithmic': 16,
#           'collaborate': 80,
#           'splunk': 3,
#           'spark': 47,
#           'apache': 14,
#           'design': 219,
#           'frameworks': 25,
#           'mentoring': 16,
#           'writing': 86,
#           'scala': 13,
#           'safe': 37,
#           'kinesis': 3,
#           'kafka': 9,
#           'algorithms': 50,
#           'ml': 3,
#           'ansible': 2,
#           'metadata': 27,
#           'banking': 17,
#           'etl': 83,
#           'english': 13,
#           'json': 36,
#           'saas': 13,
#           'clojure': 2,
#           'bi': 165,
#           'analyze': 256,
#           'datasets': 49,
#           'tableau': 110,
#           'research': 108,
#           'analytical': 209,
#           'mongodb': 28,
#           'bachelors': 17,
#           'robotics': 2,
#           'model': 66,
#           'lamp': 2,
#           'bootstrap': 6,
#           'twitter': 7,
#           'linkedin': 3,
#           'phd': 30,
#           'efficiency': 46,
#           'net': 3,
#           'fintech': 2,
#           'targeting': 13,
#           'dom': 1,
#           'nlp': 12,
#           'nodejs': 6,
#           'd3': 13,
#           'visualization': 172,
#           'acquisition': 13,
#           'self-motivated': 46,
#           'streaming': 8,
#           'perl': 62,
#           'solr': 10,
#           's3': 8,
#           'emr': 8,
#           'hardware': 18,
#           'unstructured': 23,
#           'petabyte': 4,
#           'os': 10,
#           'desktop': 13,
#           'mapreduce': 8,
#           'pytorch': 3,
#           'tensorflow': 6,
#           'scikit-learn': 10,
#           'keras': 3,
#           'analyses': 52,
#           'regulatory': 22,
#           'workflow': 30,
#           'spss': 18,
#           'dashboards': 65,
#           'excel': 154,
#           'leadership': 118,
#           'less': 21,
#           'prototyping': 34,
#           'physics': 20,
#           'economics': 98,
#           'mathematics': 128,
#           'detail-oriented': 26,
#           'analyzing': 58,
#           'xml': 27,
#           'imaging': 5,
#           'sensors': 17,
#           'bs': 24,
#           'ph.d.': 7,
#           'classification': 37,
#           'website': 23,
#           'clustering': 38,
#           'sampling': 2,
#           'shiny': 3,
#           'erp': 22,
#           'qlik': 25,
#           'mentor': 24,
#           'prioritize': 61,
#           'principle': 1,
#           'sharepoint': 14,
#           'mathematical': 17,
#           'powerpoint': 57,
#           'ssrs': 30,
#           'multi-task': 29,
#           'measurement': 13,
#           'segmentation': 17,
#           'optimize': 27,
#           'arcgis': 16,
#           'algorithm': 12,
#           'troubleshooting': 43,
#           'websites': 4,
#           'logic': 27,
#           'gis': 28,
#           'numpy': 27,
#           'seaborn': 2,
#           'python3': 2,
#           'regression': 34,
#           'urllib': 2,
#           'geodatabase': 13,
#           'geojson': 28,
#           'd3js': 5,
#           'carto': 5,
#           'bigdata': 22,
#           'markov': 5,
#           'geokettle': 14,
#           'broadcast': 19,
#           'math': 70,
#           'matlab': 84,
#           'gdal': 5,
#           'postgis': 14,
#           'photoshop': 12,
#           'kettle': 14,
#           'seo': 12,
#           'extjs': 5,
#           'illustrator': 6,
#           'opencv': 5,
#           'ogr2ogr': 5,
#           'ftp': 14,
#           'simulation': 23,
#           'n-grams': 5,
#           'css3': 5,
#           'octave': 5,
#           'k-means': 17,
#           'informatica': 28,
#           'cartodb': 10,
#           'esri': 15,
#           'couchdb': 6,
#           'geoserver': 17,
#           'html5': 5,
#           'mongdb': 5,
#           'clarity': 10,
#           'instagram': 1,
#           'hive': 52,
#           'quicksight': 1,
#           'presto': 4,
#           'circonus': 1,
#           'databricks': 1,
#           'sas': 40,
#           'teradata': 11,
#           'groovy': 3,
#           'object-oriented': 3,
#           'budgeting': 15,
#           'sap': 16,
#           'batch': 9,
#           'templates': 10,
#           'powerbi': 7,
#           'econometric': 7,
#           'stata': 16,
#           'julia': 2,
#           'econometrics': 8,
#           'windows': 20,
#           't-sql': 12,
#           'spotfire': 20,
#           'multitasking': 6,
#           'map/reduce': 6,
#           'biostatistics': 4,
#           'ar': 2,
#           'attention-to-detail': 1,
#           'e2e': 1,
#           'epic': 9,
#           'caboodle': 8,
#           'pig': 12,
#           'cognitive': 2,
#           'caffe': 1,
#           'scipy': 4,
#           'slq': 4,
#           'socrata': 6,
#           'svn': 7,
#           'openrefine': 6,
#           'rdbms/dba': 6,
#           'big-data': 3,
#           'graphs': 1,
#           'accessibility': 4,
#           'bioinformatics': 8,
#           'self-directed': 17,
#           'alteryx': 13,
#           'telecommunications': 13,
#           'stem': 2,
#           'macros': 2,
#           'lean': 8,
#           'gephi': 3,
#           'time-management': 7,
#           'cap': 1,
#           'demography': 2,
#           'mba': 9,
#           'wireframes': 3,
#           'visualizing': 5,
#           'bigtable': 1,
#           'statsmodels': 3,
#           'hpc': 2,
#           'a/b': 5,
#           'scheduling': 3,
#           'storm': 4,
#           'kibana': 1,
#           'statistician': 3,
#           'h20': 2,
#           'bayesian': 2,
#           'inference': 3,
#           'fpga': 1,
#           'cfa': 1,
#           'composition': 2}),
#  'python': Counter({'development': 266,
#           'python': 1312,
#           'analytics': 282,
#           'ansible': 25,
#           'botnet': 4,
#           'developer': 133,
#           'networking': 22,
#           'linux': 150,
#           'qa': 14,
#           'hardware': 25,
#           'social': 48,
#           'unix': 14,
#           'aws': 164,
#           'design': 193,
#           'algorithms': 86,
#           'django': 92,
#           'engineers': 213,
#           'hierarchy': 5,
#           'javascript': 453,
#           'java': 302,
#           'kibana': 2,
#           'redis': 38,
#           'spark': 82,
#           'docker': 98,
#           'statistical': 102,
#           'elasticsearch': 80,
#           'angularjs': 34,
#           'analysis': 390,
#           'c++': 93,
#           'git': 82,
#           'julia': 10,
#           'c': 85,
#           'code': 131,
#           'api': 58,
#           'postgresql': 69,
#           'kafka': 35,
#           'research': 143,
#           'apache': 23,
#           'software': 381,
#           'app': 44,
#           'web': 336,
#           'metadata': 17,
#           'apps': 37,
#           'backend': 202,
#           'engineering': 576,
#           'android': 50,
#           'github': 19,
#           'ios': 41,
#           'windows': 24,
#           'analysts': 112,
#           'coding': 106,
#           'ai': 39,
#           'front-end': 49,
#           'programming': 328,
#           'tensorflow': 31,
#           'angular': 25,
#           'back-end': 30,
#           'caffe': 5,
#           'hadoop': 61,
#           'ui': 27,
#           'cloud': 95,
#           'bigtable': 4,
#           'stack': 234,
#           'scala': 51,
#           'bi': 51,
#           'ruby': 83,
#           'presto': 10,
#           'ml': 29,
#           'mysql': 38,
#           'frontend': 72,
#           'react': 164,
#           'nodejs': 18,
#           'ux': 25,
#           'modeling': 204,
#           'lean': 5,
#           'simulation': 27,
#           'classification': 33,
#           'full-stack': 50,
#           'bayesian': 6,
#           'collaborative': 52,
#           'node': 36,
#           'prototyping': 44,
#           'apis': 34,
#           'xml': 16,
#           'communication': 168,
#           'restful': 6,
#           'access': 80,
#           'leadership': 79,
#           'postgres': 57,
#           'mobile': 94,
#           'agile': 134,
#           'analyst': 99,
#           'it': 72,
#           'd3': 28,
#           'scikit-learn': 23,
#           'pandas': 66,
#           'numpy': 87,
#           'frameworks': 44,
#           'datasets': 45,
#           'keras': 13,
#           'english': 15,
#           'healthcare': 38,
#           'efficiency': 33,
#           'react.js': 9,
#           'analyze': 156,
#           'investing': 13,
#           'r': 152,
#           'safe': 28,
#           'finance': 45,
#           'analyzing': 45,
#           'php': 44,
#           'node.js': 62,
#           'jquery': 44,
#           '.net': 15,
#           'server': 39,
#           'ms': 32,
#           'sql': 178,
#           'optimize': 35,
#           'analytical': 123,
#           'webpack': 10,
#           'nlp': 20,
#           'facebook': 8,
#           'bs': 23,
#           'banking': 13,
#           'redshift': 25,
#           'fintech': 15,
#           'linkedin': 5,
#           's3': 17,
#           'mobile-first': 3,
#           'database': 85,
#           'perl': 94,
#           'scripting': 56,
#           'manage': 77,
#           'clojure': 7,
#           'analyses': 49,
#           'models': 131,
#           'mongodb': 70,
#           'model': 64,
#           'self-directed': 16,
#           'js': 22,
#           'es6': 24,
#           'cap': 3,
#           'azure': 21,
#           'logic': 28,
#           'planning': 40,
#           'swift': 14,
#           'css': 24,
#           'html': 27,
#           'datastore': 1,
#           'bachelors': 10,
#           'robotics': 11,
#           'controls': 12,
#           'graphql': 15,
#           'net': 4,
#           'databases': 67,
#           'initiative': 25,
#           'tdd': 7,
#           'shell': 20,
#           'websites': 4,
#           'postgis': 18,
#           'hive': 70,
#           'website': 25,
#           'emr': 9,
#           'data-driven': 43,
#           'cryptocurrency': 4,
#           'imaging': 8,
#           'opencv': 6,
#           'statistics': 186,
#           'interpersonal': 35,
#           'kinesis': 12,
#           'sensors': 24,
#           'writing': 54,
#           'nginx': 8,
#           'sass': 7,
#           'dynamodb': 12,
#           'cms': 3,
#           'vue': 4,
#           'json': 36,
#           'less': 15,
#           'object-oriented': 5,
#           'principle': 4,
#           'collaborate': 62,
#           'visualization': 148,
#           'mentoring': 16,
#           'targeting': 12,
#           'analytic': 60,
#           'classifiers': 1,
#           'workflow': 19,
#           'acquisition': 15,
#           'saas': 30,
#           'solr': 12,
#           'algorithm': 28,
#           'qc': 1,
#           'bioinformatics': 20,
#           'phd': 84,
#           'prioritize': 20,
#           'bootstrap': 6,
#           'html5': 10,
#           'math': 72,
#           'biotech': 2,
#           'physics': 52,
#           'hpc': 10,
#           'cs': 10,
#           'oracle': 46,
#           'sharepoint': 5,
#           'gulp': 3,
#           'scrum': 14,
#           'desktop': 12,
#           'malware': 12,
#           'splunk': 5,
#           'algorithmic': 30,
#           'ar': 2,
#           'mathematical': 17,
#           'optimization': 74,
#           'measurement': 10,
#           'etl': 35,
#           'twitter': 7,
#           'regression': 40,
#           'ph.d.': 8,
#           'pytorch': 5,
#           'accessibility': 4,
#           'nosql': 33,
#           'dashboards': 13,
#           'tableau': 45,
#           'svg': 3,
#           'visualizing': 6,
#           'inference': 7,
#           'regulatory': 21,
#           'pharmaceutical': 1,
#           'os': 16,
#           'matlab': 152,
#           'segmentation': 7,
#           'sas': 30,
#           'sketch': 2,
#           'seo': 11,
#           'clarity': 5,
#           'gabi': 1,
#           'biotechnology': 5,
#           'scipy': 6,
#           'cross-browser': 1,
#           'animation': 1,
#           'couchdb': 6,
#           'shiny': 4,
#           'statistician': 4,
#           'unstructured': 27,
#           'petabyte': 5,
#           'batch': 10,
#           'scheduling': 3,
#           'excel': 40,
#           'macros': 2,
#           'vfx': 1,
#           'troubleshooting': 36,
#           'streaming': 9,
#           'self-motivated': 31,
#           'mapreduce': 7,
#           'lamp': 1,
#           'parquet': 3,
#           'economics': 58,
#           'mathematics': 132,
#           'clustering': 40,
#           'sampling': 1,
#           'arcgis': 17,
#           'gis': 26,
#           'detail-oriented': 15,
#           'seaborn': 2,
#           'python3': 2,
#           'urllib': 2,
#           'geodatabase': 12,
#           'geojson': 28,
#           'adobe': 5,
#           'd3js': 5,
#           'carto': 5,
#           'bigdata': 24,
#           'markov': 5,
#           'geokettle': 14,
#           'broadcast': 16,
#           'gdal': 5,
#           'photoshop': 10,
#           'kettle': 14,
#           'extjs': 5,
#           'illustrator': 5,
#           'ogr2ogr': 5,
#           'ftp': 14,
#           'n-grams': 5,
#           'css3': 5,
#           'octave': 5,
#           'k-means': 18,
#           'informatica': 20,
#           'cartodb': 10,
#           'esri': 17,
#           'geoserver': 16,
#           'mongdb': 5,
#           'quicksight': 1,
#           'circonus': 1,
#           'databricks': 1,
#           'powerpoint': 14,
#           'templates': 5,
#           'powerbi': 7,
#           'econometric': 4,
#           'stata': 10,
#           'multi-task': 6,
#           'econometrics': 12,
#           'spotfire': 9,
#           'multitasking': 4,
#           'm.b.a.': 2,
#           'biostatistics': 3,
#           'e2e': 1,
#           'telecommunications': 10,
#           'personalization': 4,
#           'graphx': 2,
#           'pig': 9,
#           'cognitive': 2,
#           'mentor': 16,
#           'map/reduce': 4,
#           'slq': 4,
#           'socrata': 6,
#           'svn': 7,
#           'openrefine': 6,
#           'rdbms/dba': 6,
#           'cron': 6,
#           'crm': 2,
#           'qlikview': 6,
#           'big-data': 4,
#           'sap': 7,
#           'qlik': 7,
#           'alteryx': 9,
#           'erp': 3,
#           'stem': 2,
#           'cfa': 4,
#           'frm': 7,
#           'gephi': 3,
#           'ransomware': 3,
#           'netflow': 3,
#           'phishing': 3,
#           'time-management': 3,
#           'storm': 5,
#           'statsmodels': 3,
#           'opengl': 3,
#           'ssrs': 2,
#           'budgeting': 3,
#           'mba': 2,
#           'epic': 3,
#           'caboodle': 3,
#           'micro-controllers': 1,
#           'fpga': 1,
#           'biophysics': 2,
#           'spicy': 2,
#           'teradata': 3,
#           'idl': 3,
#           'h20': 2,
#           'spss': 1,
#           'a/b': 2,
#           'wireframes': 1}),
#  'javascript': Counter({'algorithms': 24,
#           'django': 35,
#           'engineers': 111,
#           'hierarchy': 5,
#           'javascript': 1056,
#           'java': 154,
#           'python': 302,
#           'kibana': 2,
#           'redis': 24,
#           'spark': 19,
#           'docker': 37,
#           'ansible': 10,
#           'statistical': 14,
#           'elasticsearch': 54,
#           'linux': 80,
#           'angularjs': 40,
#           'analysis': 134,
#           'c++': 29,
#           'git': 56,
#           'julia': 3,
#           'c': 51,
#           'code': 105,
#           'api': 44,
#           'postgresql': 39,
#           'kafka': 20,
#           'research': 37,
#           'apache': 6,
#           'graphql': 13,
#           'full-stack': 50,
#           'development': 144,
#           'saas': 20,
#           'mobile': 70,
#           'front-end': 51,
#           'efficiency': 7,
#           'react.js': 14,
#           'developer': 116,
#           'writing': 34,
#           'english': 12,
#           'react': 137,
#           'ruby': 55,
#           'analytics': 116,
#           'redshift': 6,
#           'qa': 16,
#           'cloud': 58,
#           'social': 18,
#           'engineering': 266,
#           'facebook': 11,
#           'collaborative': 27,
#           'nodejs': 14,
#           'backend': 126,
#           'ui': 28,
#           'ux': 19,
#           'frontend': 47,
#           'software': 220,
#           'safe': 4,
#           'phd': 8,
#           'manage': 37,
#           'node': 30,
#           'postgres': 29,
#           'stack': 165,
#           'web': 286,
#           'agile': 104,
#           'programming': 132,
#           'analyst': 29,
#           'aws': 76,
#           'it': 47,
#           'mysql': 29,
#           'pandas': 16,
#           'numpy': 27,
#           'frameworks': 37,
#           'ml': 10,
#           'tensorflow': 6,
#           'scikit-learn': 6,
#           'datasets': 12,
#           'keras': 4,
#           'analyze': 42,
#           'investing': 12,
#           'r': 32,
#           'finance': 17,
#           'analyzing': 14,
#           'php': 38,
#           'node.js': 86,
#           'jquery': 70,
#           '.net': 19,
#           'server': 34,
#           'android': 29,
#           'ms': 9,
#           'sql': 81,
#           'ios': 27,
#           'app': 32,
#           'd3': 21,
#           'back-end': 25,
#           'css': 59,
#           'sass': 14,
#           'es6': 26,
#           'html5': 25,
#           'clojure': 7,
#           'streaming': 7,
#           'angular': 23,
#           'vue': 9,
#           'leadership': 31,
#           'collaborate': 28,
#           'js': 20,
#           'less': 14,
#           'html': 59,
#           'apis': 30,
#           'restful': 6,
#           'webpack': 12,
#           'design': 108,
#           'algorithm': 13,
#           'css3': 12,
#           'fintech': 6,
#           'ai': 8,
#           'azure': 11,
#           'controls': 3,
#           'crm': 8,
#           'prototyping': 14,
#           'net': 1,
#           'access': 27,
#           'optimization': 40,
#           'scheduling': 3,
#           'healthcare': 14,
#           'scripting': 21,
#           'nlp': 8,
#           'scala': 21,
#           'swift': 10,
#           'workflow': 16,
#           'github': 14,
#           'coding': 60,
#           'cron': 9,
#           'bootstrap': 14,
#           'lean': 7,
#           'tdd': 6,
#           'apps': 17,
#           'dynamodb': 6,
#           'cms': 4,
#           'windows': 10,
#           'data-driven': 11,
#           'mobile-first': 1,
#           'principle': 3,
#           'sketch': 4,
#           'planning': 25,
#           'nosql': 31,
#           'database': 42,
#           'hardware': 12,
#           'sensors': 9,
#           'website': 25,
#           'perl': 40,
#           'circonus': 2,
#           'adobe': 18,
#           'scrum': 11,
#           'qlikview': 5,
#           'mongodb': 54,
#           'targeting': 2,
#           'hadoop': 20,
#           'visualization': 70,
#           'models': 27,
#           'analytical': 38,
#           'mentor': 5,
#           'physics': 12,
#           'modeling': 40,
#           'optimize': 13,
#           'hpc': 1,
#           'bs': 8,
#           'linkedin': 6,
#           'analyses': 5,
#           'bioinformatics': 6,
#           'cs': 6,
#           'math': 28,
#           'gulp': 7,
#           'nginx': 5,
#           'model': 19,
#           'logic': 18,
#           'communication': 63,
#           'desktop': 10,
#           'malware': 2,
#           'oracle': 17,
#           'kinesis': 4,
#           'ar': 2,
#           'prioritize': 19,
#           'simulation': 12,
#           'analysts': 64,
#           'databases': 25,
#           'unix': 4,
#           'mathematical': 6,
#           'statistics': 24,
#           'websites': 4,
#           'seo': 8,
#           'hive': 8,
#           'algorithmic': 10,
#           'sitecore': 4,
#           'detail-oriented': 4,
#           'json': 22,
#           'metadata': 9,
#           'banking': 7,
#           'etl': 30,
#           'initiative': 12,
#           'mentoring': 9,
#           'accessibility': 4,
#           'photoshop': 16,
#           'bachelors': 1,
#           'robotics': 2,
#           'self-directed': 11,
#           'acquisition': 8,
#           'cross-browser': 2,
#           's3': 4,
#           'visualizing': 1,
#           'opengl': 1,
#           'dom': 1,
#           'os': 2,
#           'templates': 4,
#           'cryptocurrency': 4,
#           'self-motivated': 26,
#           'animation': 1,
#           'b.s.': 1,
#           'ph.d.': 1,
#           'alteryx': 6,
#           'solr': 6,
#           'emr': 2,
#           'scipy': 1,
#           'imaging': 1,
#           'networking': 4,
#           'couchdb': 8,
#           'bigtable': 2,
#           'tableau': 20,
#           'svg': 2,
#           'mapreduce': 3,
#           'pytorch': 1,
#           'lamp': 1,
#           'shell': 10,
#           'regulatory': 5,
#           'geodatabase': 7,
#           'geojson': 22,
#           'd3js': 5,
#           'bi': 39,
#           'carto': 5,
#           'bigdata': 10,
#           'markov': 5,
#           'geokettle': 11,
#           'broadcast': 11,
#           'matlab': 48,
#           'gdal': 5,
#           'postgis': 11,
#           'kettle': 11,
#           'extjs': 5,
#           'illustrator': 7,
#           'opencv': 5,
#           'ogr2ogr': 5,
#           'ftp': 11,
#           'n-grams': 5,
#           'octave': 5,
#           'k-means': 11,
#           'informatica': 17,
#           'cartodb': 5,
#           'excel': 25,
#           'esri': 9,
#           'geoserver': 13,
#           'mongdb': 5,
#           'troubleshooting': 12,
#           'groovy': 7,
#           'erp': 5,
#           'dashboards': 8,
#           'interpersonal': 13,
#           'object-oriented': 7,
#           'batch': 4,
#           'mathematics': 10,
#           'powerbi': 5,
#           'unstructured': 11,
#           'gis': 13,
#           'arcgis': 4,
#           'spotfire': 5,
#           'xml': 12,
#           'e2e': 1,
#           'analytic': 20,
#           'cognitive': 6,
#           'ui/ux': 1,
#           'socrata': 6,
#           'svn': 7,
#           'openrefine': 6,
#           'rdbms/dba': 6,
#           'sap': 5,
#           'qlik': 6,
#           'powerpoint': 5,
#           'economics': 2,
#           'segmentation': 6,
#           'personalization': 4,
#           'multi-task': 4,
#           'classification': 6,
#           'telecommunications': 2,
#           'ssrs': 3,
#           'a/b': 3,
#           'sharepoint': 2,
#           'stem': 1,
#           'measurement': 1,
#           'wireframes': 1,
#           'invision': 2,
#           'branding': 1,
#           'mba': 1,
#           'twitter': 2,
#           'sas': 1}),
#  'java': Counter({'algorithms': 38,
#           'django': 10,
#           'engineers': 106,
#           'hierarchy': 2,
#           'javascript': 231,
#           'java': 614,
#           'python': 302,
#           'kibana': 2,
#           'redis': 21,
#           'spark': 47,
#           'docker': 41,
#           'ansible': 13,
#           'statistical': 41,
#           'elasticsearch': 24,
#           'linux': 78,
#           'angularjs': 18,
#           'analysis': 184,
#           'c++': 54,
#           'git': 50,
#           'julia': 3,
#           'c': 66,
#           'code': 78,
#           'api': 39,
#           'postgresql': 27,
#           'kafka': 31,
#           'research': 62,
#           'apache': 14,
#           'full-stack': 10,
#           'development': 146,
#           'software': 203,
#           'web': 218,
#           'communication': 81,
#           'developer': 70,
#           'stack': 90,
#           'databases': 39,
#           'ui': 19,
#           'nosql': 26,
#           'react': 50,
#           'scala': 45,
#           'nodejs': 4,
#           'backend': 102,
#           'qa': 14,
#           'ux': 14,
#           'frontend': 32,
#           'modeling': 82,
#           'programming': 200,
#           'lean': 5,
#           'engineering': 256,
#           'simulation': 8,
#           'aws': 64,
#           'design': 107,
#           'mobile': 78,
#           'hadoop': 46,
#           'php': 29,
#           'ruby': 66,
#           'node.js': 48,
#           'jquery': 44,
#           'mysql': 26,
#           'postgres': 14,
#           '.net': 15,
#           'server': 30,
#           'android': 49,
#           'ms': 17,
#           'sql': 83,
#           'ios': 31,
#           'perl': 58,
#           'networking': 12,
#           'scripting': 37,
#           'unix': 6,
#           'manage': 35,
#           'clojure': 4,
#           'analytics': 156,
#           'batch': 11,
#           'back-end': 19,
#           'writing': 30,
#           'etl': 21,
#           'app': 24,
#           'css': 24,
#           'html': 23,
#           'frameworks': 23,
#           'd3': 1,
#           'sass': 4,
#           'es6': 7,
#           'html5': 8,
#           'streaming': 16,
#           'angular': 19,
#           'vue': 5,
#           'leadership': 33,
#           'ai': 15,
#           'apis': 21,
#           'nginx': 7,
#           'phd': 28,
#           'mathematical': 7,
#           'collaborate': 43,
#           'js': 8,
#           'less': 4,
#           'coding': 66,
#           'azure': 19,
#           'agile': 110,
#           'social': 26,
#           'logic': 16,
#           'ml': 5,
#           'cloud': 61,
#           'model': 23,
#           's3': 8,
#           'appengine': 1,
#           'datastore': 1,
#           'swift': 15,
#           'graphql': 5,
#           'node': 14,
#           'websites': 2,
#           'r': 53,
#           'tdd': 6,
#           'front-end': 21,
#           'healthcare': 12,
#           'optimize': 15,
#           'object-oriented': 15,
#           'apps': 20,
#           'analysts': 42,
#           'access': 36,
#           'data-driven': 16,
#           'analyst': 42,
#           'acquisition': 15,
#           'mentoring': 15,
#           'banking': 5,
#           'optimization': 38,
#           'webpack': 14,
#           'crm': 10,
#           'personalization': 1,
#           'saas': 16,
#           'it': 41,
#           'circonus': 3,
#           'tensorflow': 6,
#           'keras': 4,
#           'fintech': 3,
#           'finance': 10,
#           'classifiers': 1,
#           'models': 37,
#           'math': 10,
#           'datasets': 22,
#           'database': 48,
#           'cs': 8,
#           'oracle': 26,
#           'bs': 18,
#           'react.js': 5,
#           'imaging': 10,
#           'desktop': 6,
#           'pandas': 18,
#           'numpy': 9,
#           'website': 15,
#           'physics': 28,
#           'gulp': 3,
#           'visualization': 44,
#           'scikit-learn': 7,
#           'postgis': 7,
#           'redshift': 8,
#           'mongodb': 50,
#           'interpersonal': 14,
#           'json': 30,
#           'dynamodb': 11,
#           'collaborative': 18,
#           'hive': 40,
#           'metadata': 5,
#           'initiative': 14,
#           'twitter': 4,
#           'english': 2,
#           'efficiency': 12,
#           'analytical': 56,
#           'bachelors': 6,
#           'robotics': 3,
#           'facebook': 3,
#           'lamp': 2,
#           'bootstrap': 6,
#           'planning': 23,
#           'dashboards': 9,
#           'windows': 10,
#           'algorithm': 11,
#           'regulatory': 7,
#           'cross-browser': 1,
#           'workflow': 10,
#           'visualizing': 4,
#           'opengl': 1,
#           'github': 7,
#           'net': 1,
#           'targeting': 3,
#           'dom': 1,
#           'linkedin': 1,
#           'sensors': 7,
#           'kinesis': 7,
#           'solr': 5,
#           'emr': 5,
#           'css3': 1,
#           'safe': 13,
#           'couchdb': 2,
#           'accessibility': 2,
#           'statistician': 4,
#           'prototyping': 20,
#           'scipy': 1,
#           'unstructured': 16,
#           'investing': 10,
#           'scheduling': 1,
#           'os': 6,
#           'scrum': 11,
#           'hardware': 11,
#           'self-motivated': 20,
#           'analyses': 19,
#           'mapreduce': 8,
#           'pytorch': 3,
#           'shell': 10,
#           'statistics': 68,
#           'economics': 8,
#           'mathematics': 66,
#           'xml': 14,
#           'ph.d.': 11,
#           'controls': 5,
#           'analyze': 64,
#           'sas': 11,
#           'prioritize': 14,
#           'self-directed': 12,
#           'troubleshooting': 16,
#           'splunk': 1,
#           'quicksight': 1,
#           'presto': 3,
#           'databricks': 1,
#           'tableau': 15,
#           'groovy': 8,
#           'bi': 29,
#           'erp': 7,
#           'templates': 8,
#           'powerbi': 5,
#           'informatica': 9,
#           'bioinformatics': 16,
#           'analytic': 22,
#           'measurement': 5,
#           'regression': 11,
#           'detail-oriented': 5,
#           'analyzing': 22,
#           'biotechnology': 3,
#           'excel': 13,
#           'mentor': 10,
#           'e2e': 1,
#           'cognitive': 6,
#           'matlab': 72,
#           'algorithmic': 20,
#           'gis': 8,
#           'geojson': 12,
#           'socrata': 6,
#           'geokettle': 6,
#           'broadcast': 6,
#           'svn': 8,
#           'kettle': 6,
#           'openrefine': 6,
#           'ftp': 6,
#           'rdbms/dba': 6,
#           'cron': 6,
#           'k-means': 6,
#           'geoserver': 6,
#           'classification': 18,
#           'qlikview': 3,
#           'clustering': 18,
#           'econometrics': 2,
#           'powerpoint': 3,
#           'arcgis': 4,
#           'esri': 1,
#           'sap': 4,
#           'telecommunications': 4,
#           'ssrs': 2,
#           'restful': 2,
#           't-sql': 1,
#           'stata': 6,
#           'gephi': 3,
#           'malware': 7,
#           'qlik': 6,
#           'ransomware': 3,
#           'botnet': 3,
#           'netflow': 3,
#           'petabyte': 4,
#           'phishing': 3,
#           'principle': 1,
#           'storm': 5,
#           'pig': 7,
#           'bigtable': 1,
#           'segmentation': 2,
#           'spotfire': 6,
#           'big-data': 1,
#           'branding': 1,
#           'multi-task': 2,
#           'stem': 1,
#           'micro-controllers': 1,
#           'mba': 1,
#           'nlp': 2,
#           'h20': 2,
#           'bayesian': 2,
#           'inference': 3,
#           'alteryx': 1,
#           'bigdata': 2,
#           'adobe': 1,
#           'seo': 1,
#           'hpc': 1}),
#  'excel': Counter({'software': 181,
#           'python': 80,
#           'developer': 19,
#           'back-end': 3,
#           'writing': 113,
#           'excel': 546,
#           'finance': 190,
#           'macros': 17,
#           'c': 11,
#           'code': 31,
#           'development': 309,
#           'bi': 114,
#           'healthcare': 57,
#           'analytics': 312,
#           'statistics': 154,
#           'models': 111,
#           'modeling': 264,
#           'r': 64,
#           'analyses': 78,
#           'statistical': 85,
#           'analytical': 273,
#           'regulatory': 46,
#           'communication': 386,
#           'analytic': 98,
#           'workflow': 19,
#           'spss': 24,
#           'analyst': 328,
#           'safe': 60,
#           'analysis': 724,
#           'database': 111,
#           'collaborative': 69,
#           'dashboards': 67,
#           'access': 176,
#           'sql': 154,
#           'leadership': 157,
#           'manage': 210,
#           'research': 180,
#           'design': 158,
#           'analysts': 210,
#           'analyze': 368,
#           'powerpoint': 192,
#           'analyzing': 69,
#           'engineers': 50,
#           'imaging': 21,
#           'acquisition': 22,
#           'sensors': 33,
#           'bs': 18,
#           'ph.d.': 20,
#           'ms': 178,
#           'databases': 97,
#           'bachelors': 22,
#           'net': 8,
#           'lean': 23,
#           'model': 78,
#           'planning': 157,
#           'azure': 7,
#           'mysql': 6,
#           'visualization': 88,
#           'cloud': 34,
#           'engineering': 274,
#           'server': 33,
#           'oracle': 47,
#           'less': 19,
#           'etl': 32,
#           'tableau': 72,
#           'aws': 4,
#           'it': 159,
#           'sap': 26,
#           'initiative': 82,
#           'efficiency': 71,
#           'economics': 172,
#           'mathematics': 96,
#           'stata': 8,
#           'sas': 28,
#           'multi-task': 58,
#           'classification': 22,
#           'sharepoint': 24,
#           'programming': 90,
#           'cms': 4,
#           'mathematical': 31,
#           'collaborate': 92,
#           'data-driven': 23,
#           'web': 102,
#           'social': 46,
#           'prioritize': 85,
#           'mobile': 34,
#           'agile': 90,
#           'crm': 24,
#           'api': 8,
#           'scrum': 6,
#           'metadata': 12,
#           'interpersonal': 143,
#           'qlik': 12,
#           'ssrs': 15,
#           'frameworks': 8,
#           'react': 1,
#           'hardware': 21,
#           'measurement': 28,
#           'app': 8,
#           'apps': 9,
#           'templates': 18,
#           'detail-oriented': 23,
#           'mentoring': 19,
#           'controls': 42,
#           'linkedin': 5,
#           'scheduling': 19,
#           'troubleshooting': 21,
#           'websites': 4,
#           'logic': 19,
#           'english': 15,
#           'principle': 9,
#           'budgeting': 45,
#           'self-motivated': 50,
#           'gis': 14,
#           'desktop': 12,
#           'geodatabase': 5,
#           'perl': 24,
#           'algorithms': 15,
#           'php': 8,
#           'coding': 60,
#           'javascript': 75,
#           'geojson': 10,
#           'adobe': 17,
#           'd3js': 5,
#           'carto': 5,
#           'bigdata': 10,
#           'nodejs': 5,
#           'markov': 5,
#           'geokettle': 5,
#           'broadcast': 6,
#           'jquery': 14,
#           'hadoop': 11,
#           'math': 90,
#           'matlab': 48,
#           'd3': 5,
#           'gdal': 5,
#           'solr': 5,
#           'postgis': 5,
#           'elasticsearch': 10,
#           'photoshop': 10,
#           'kettle': 5,
#           'seo': 8,
#           'extjs': 5,
#           'nosql': 9,
#           'illustrator': 5,
#           'opencv': 5,
#           'nlp': 5,
#           'ogr2ogr': 5,
#           'ftp': 5,
#           'algorithm': 7,
#           'simulation': 14,
#           'n-grams': 5,
#           'css3': 5,
#           'octave': 5,
#           'k-means': 5,
#           'informatica': 5,
#           'stack': 12,
#           'cartodb': 5,
#           'esri': 7,
#           'couchdb': 5,
#           'geoserver': 5,
#           'html5': 5,
#           'mongdb': 5,
#           'optimization': 78,
#           'optimize': 42,
#           'phd': 18,
#           'pharmaceutical': 11,
#           'emr': 7,
#           'self-directed': 14,
#           'website': 28,
#           'arcgis': 3,
#           'storm': 1,
#           'segmentation': 17,
#           'm.a.': 4,
#           'bayesian': 4,
#           'unstructured': 9,
#           'regression': 19,
#           'windows': 18,
#           'saas': 4,
#           'front-end': 1,
#           'css': 8,
#           '.net': 3,
#           'bootstrap': 1,
#           'html': 13,
#           'object-oriented': 3,
#           'erp': 30,
#           'datasets': 13,
#           'investing': 6,
#           'cap': 4,
#           'sampling': 8,
#           'banking': 25,
#           'cfa': 13,
#           'java': 26,
#           'scripting': 17,
#           'apache': 4,
#           'multitasking': 8,
#           'hive': 6,
#           'map/reduce': 2,
#           'mentor': 20,
#           'time-management': 3,
#           'groovy': 1,
#           'xml': 5,
#           'ui': 3,
#           'qc': 5,
#           'accessibility': 7,
#           'apis': 10,
#           'e2e': 1,
#           'os': 4,
#           'composition': 7,
#           'attention-to-detail': 2,
#           'qa': 17,
#           'spark': 6,
#           'unix': 4,
#           'twitter': 11,
#           'graphs': 8,
#           'mba': 22,
#           'backend': 4,
#           'telecommunications': 24,
#           'networking': 7,
#           'mongodb': 4,
#           'linux': 12,
#           'biotechnology': 3,
#           'facebook': 11,
#           'instagram': 4,
#           'spotfire': 10,
#           'physics': 16,
#           'stem': 6,
#           'frm': 4,
#           'c++': 6,
#           'targeting': 8,
#           'shell': 4,
#           'prototyping': 4,
#           'postgresql': 4,
#           'streaming': 3,
#           'demography': 2,
#           'personalization': 6,
#           'teradata': 5,
#           'json': 4,
#           'alteryx': 5,
#           'epic': 5,
#           't-sql': 3,
#           'econometric': 3,
#           'petabyte': 3,
#           'a/b': 4,
#           'qlikview': 4,
#           'ar': 2,
#           'data-sets': 2,
#           'ruby': 3,
#           'cs': 2,
#           'swift': 2,
#           'robotics': 1,
#           'goldset': 1,
#           'gabi': 1,
#           'traci': 1,
#           'simapro': 1,
#           'biostatistics': 2,
#           'econometrics': 1,
#           'powerbi': 1,
#           'biochemistry': 1,
#           'pig': 1,
#           'inference': 2,
#           'shiny': 2,
#           'biotech': 1,
#           'lcms': 1,
#           'clarity': 3,
#           'pbx': 1,
#           'wireframes': 1,
#           'handoff': 1,
#           'redshift': 1,
#           's3': 1,
#           'animation': 1,
#           'ai': 1,
#           'postgres': 1})}

# %%
# Pie chart
labels = matches.keys()
sizes = matches.values()
fig1, ax1 = plt.subplots()
fig1.set_size_inches(4,4)
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', pctdistance=0.8, labeldistance=1.3,
        shadow=True, startangle=90)
#plt.title('% of Skills')
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
ax1.axis('equal')  
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-f57b209e95d2> in <module>()
#       1 # Pie chart
# ----> 2 labels = matches.keys()
#       3 sizes = matches.values()
#       4 fig1, ax1 = plt.subplots()
#       5 fig1.set_size_inches(4,4)
#
# NameError: name 'matches' is not defined

# %%
glob.glob('*.csv')
# Out:
# ['skill_phrases.csv',
#  'skill_phrases_purged-JBM.csv',
#  'skill_phrases_purged.csv',
#  'hacker_news.csv',
#  'skill_phrases-JBM.csv']

# %%
df1=pd.read_csv('hacker_news.csv')
del df1['source']

# %%
df1.head()
# Out:
#                                                 desc
# 0  Photofeeler (<a href="https:&#x2F;&#x2F;www.ph...
# 1  Q-Branch Labs (<a href="https:&#x2F;&#x2F;www....
# 2  Worldwide, REMOTE, full time or part time -- 1...
# 3  Lendable | Senior Software Engineers, Senior D...
# 4  Gambit Research Ltd (<a href="http:&#x2F;&#x2F...

# %%
#del df1['source']
df1.head()
# Out:
#                                                 desc
# 0  Photofeeler (<a href="https:&#x2F;&#x2F;www.ph...
# 1  Q-Branch Labs (<a href="https:&#x2F;&#x2F;www....
# 2  Worldwide, REMOTE, full time or part time -- 1...
# 3  Lendable | Senior Software Engineers, Senior D...
# 4  Gambit Research Ltd (<a href="http:&#x2F;&#x2F...

# %%
mark_list = df1.job_summary.tolist()
mark_list[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-7691f57f2ccd> in <module>()
# ----> 1 mark_list = df1.job_summary.tolist()
#       2 mark_list[0]
#
# /Applications/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'job_summary'

# %%
mark_list = [x.replace('\<a href="https:&#x2F;&#x2F;www.photofeeler.com"', " ").replace("\x92s", " ") for x in mark_list]

# %%
mark_list[0]

# %%
df1.shape

# %%
df1.rename(columns={'desc': 'job_summary'}, inplace=True)
df1.head()

# %%
df_merged=pd.concat([df1,jobs])

# %%
df_merged.head()

# %%
print(df_merged.job_summary.unique().shape)
print(df_merged.shape)

# %%
for index, row in jobs.iterrows():
    
    job_desc = row.job_summary

    #job_tokens = nltk.word_tokenize(job_desc)
    
    job_tokens = [word_tokenize(word) for word in tqdm(job_desc)]
    
    
    #job_tokens = [word for word in job_tokens if len(word) >= 1] # remove space 
    
    #job_tokens = [word for word in job_tokens if not word in stop_words] # remove english language stop words 
    
    #job_tokens = [word.lower().strip() for word 
                  #in job_tokens if not word in string.punctuation ] #

# %%
len(job_tokens)

# %%
match_found = 0
search_keyword= "data"
matching_skill= search_keyword in job_tokens
    
if matching_skill:
    match_found +=1
    matches= defaultdict(int)  
        
    for skill in list_of_skills:
        if (skill in job_tokens) & (skill !=search_keyword):
            matches[skill] += 1

# %%
match_found
